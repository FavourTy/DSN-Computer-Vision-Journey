# %%
import cv2 as cv
from matplotlib import pyplot as plt
import torch 

img = cv.imread('../assets/pratice.jpg')
rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(rgb)

# %%
rgb = cv.resize(rgb, (20,15))

plt.imshow(rgb)

# %%
#convert to grayscale

gray = cv.cvtColor(rgb, cv.COLOR_RGB2GRAY)
plt.imshow(gray, cmap= 'gray')

# %%
#convolution

gray[0]
# Out:
# array([228, 240, 241, 170, 240,  29,  69,  75,  47,  44,  44,  73,  81,
#        212, 211, 167, 202, 195, 231, 232], dtype=uint8)

# %%
gray
# Out:
# array([[228, 240, 241, 170, 240,  29,  69,  75,  47,  44,  44,  73,  81,
#         212, 211, 167, 202, 195, 231, 232],
#        [240, 240, 240, 183, 233,  72, 138, 208, 167, 139, 136,  30, 132,
#         103, 202, 198, 201,  53, 138, 212],
#        [241, 240, 241,  76, 109, 175, 161, 125, 171,  36,  82,  20,  19,
#          38,  21,  63,  41,  21, 161, 186],
#        [240, 240, 174,  60, 189,  18, 150,  38, 127, 240,  24,  21,  13,
#          19, 108,  14,  35, 178, 152, 167],
#        [239, 174,  18, 120,  23,  21, 129,  19, 105, 158,  22,  67,  27,
#          23, 113,  39,  18, 119, 150, 165],
#        [168, 123, 207,  37,  21,  15,  20,  26,  23, 161, 127,  15, 108,
#          28,  17,  19, 155, 127, 133, 155],
#        [171,  64, 127,  37,  21,  16,  74,  41, 163, 165, 151,  33,  14,
#         125,  17,  14, 141, 101, 109,  95],
#        [129,  89,  81,  43,  17,  42,  50, 146, 114,  81,  22,  22,  22,
#         106,  95,  26, 128, 127, 151, 150],
#        [ 64,  84,  42,  13, 190, 163, 177, 161,  27, 119, 140, 137,  67,
#         112,  87,  88,  43, 140,  67,  14],
#        [ 71, 147,  19,  16, 189, 175, 178,  18,  15,  28,  96,  11,  55,
#          35, 107,  41,  73, 123, 122,  16],
#        [ 36,  16,  34,  44,  20,  21,  24,  20,  10,  10,  30,  64,  88,
#          11,  10,  10,  97,  83,  17,  53],
#        [ 29,  17,  39,  16,  17,  19,  14,  17,  21,   9,  35,  24,  21,
#          10,  77,  10,  11,  15,  18,  63],
#        [ 20,  21,  22,  20,  16,  13,  13,  16,  17,  14,  22,  23,  55,
#          50, 118, 125,  15,  16,  16,  17],
#        [174, 176,  37,  24, 203,  15,  12,  18,  17,  13,  17,  21,  36,
#          60,  44,  47,  34, 204,  31,  32],
#        [ 27,  26,  47,  30,  26,  22,  21,  25, 202,  16,  83,  16, 131,
#         109,  82, 110, 107, 148,  97, 165]], dtype=uint8)

# %%
#create a kernel
# Out:
#   Cell In[7], line 2
#     import torch as
#                    ^
# SyntaxError: invalid syntax
